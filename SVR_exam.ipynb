# %%
# !pip install pandas
# !pip install pylab
# !pip install numpy
# !pip install scipy
# !pip install sklearn
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.22.0)
# Requirement already satisfied: six>=1.5 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 21.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\kwnst\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ERROR: Could not find a version that satisfies the requirement pylab (from versions: none)
# ERROR: No matching distribution found for pylab
# WARNING: You are using pip version 21.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\kwnst\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: numpy in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (1.22.0)
# WARNING: You are using pip version 21.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\kwnst\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: scipy in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from scipy) (1.22.0)
# WARNING: You are using pip version 21.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\kwnst\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: sklearn in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from sklearn) (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.8.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.22.0)
# WARNING: You are using pip version 21.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\kwnst\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: matplotlib in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (3.5.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.0.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.28.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.22.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: You are using pip version 21.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\kwnst\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import pylab as pl
import numpy as np
import scipy.optimize as opt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("data.xlsx" , "data")
df
# Out:
#           Date  OilPrice  NaturalGasPrices  USDEUR           BTC     Gold  \
# 0   2021-01-04     50.37              2.60  1.2254           NaN  1943.20
# 1   2021-01-05     53.16              2.77  1.2295  33992.429688  1940.35
# 2   2021-01-06     53.80              2.76  1.2290  36824.363281  1931.95
# 3   2021-01-07     53.70              2.81  1.2265  39371.042969  1920.10
# 4   2021-01-08     55.51              2.77  1.2252  40797.609375  1862.90
# ..         ...       ...               ...     ...           ...      ...
# 337 2022-04-22    105.15              6.59  1.0790  39740.320313  1941.55
# 338 2022-04-25     99.27              6.42  1.0717  40458.308594  1895.00
# 339 2022-04-26     99.27              6.89  1.0643  38117.460938  1904.60
# 340 2022-04-27     99.27              6.89  1.0572  39241.121094  1885.80
# 341 2022-04-28       NaN               NaN     NaN  39773.828125      NaN
#
#        USDGBP  DowJones
# 0    0.730770  30223.89
# 1    0.736833  30391.60
# 2    0.733700  30829.40
# 3    0.733930  31041.13
# 4    0.736940  31097.97
# ..        ...       ...
# 337  0.767680  33811.40
# 338  0.779370  34049.46
# 339  0.784930  33240.18
# 340  0.794660  33301.93
# 341       NaN       NaN
#
# [342 rows x 8 columns]

# %%
df.describe()
# Out:
#          OilPrice  NaturalGasPrices      USDEUR           BTC         Gold  \
# count  341.000000        341.000000  341.000000    341.000000   341.000000
# mean    78.245982          4.186950    1.166090  46040.176996  1820.646334
# std     16.114617          1.647858    0.040105   8898.843886    65.893538
# min     50.370000          2.430000    1.057200  29807.347656  1683.950000
# 25%     68.000000          2.960000    1.132400  39187.328125  1779.050000
# 50%     74.250000          4.020000    1.175800  44895.097656  1805.200000
# 75%     84.420000          4.930000    1.200300  53333.539063  1859.900000
# max    133.180000         23.860000    1.229500  67566.828125  2039.050000
#
#            USDGBP      DowJones
# count  341.000000    341.000000
# mean     0.732680  34194.049150
# std      0.016454   1510.404999
# min      0.702900  29982.620000
# 25%      0.721370  33730.890000
# 50%      0.729800  34529.450000
# 75%      0.741200  35208.510000
# max      0.794660  36799.650000

# %%
X = df.copy()
X = X.drop(columns=['USDEUR', 'Date'])
X = X.fillna(X.mean()) #replace NaNs with the mean value

y = df['USDEUR'].copy()
y = y.fillna(y.mean())

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (273, 6) (273,)
# Test set: (69, 6) (69,)

# %%
mean_X_train=np.mean(X_train)
std_X_train=np.std(X_train)
# print(std_X_train)
X_train = (X_train - mean_X_train)/std_X_train


mean_y_train=np.mean(y_train)
std_y_train=np.std(y_train)
y_train=(y_train-mean_y_train)/std_y_train
y_train


## apply same transformation to test data
X_test = (X_test-mean_X_train)/std_X_train  # remove mean and standard deviation from test
y_test = (y_test-mean_y_train)/std_y_train
X_train
# Out:
#      OilPrice  NaturalGasPrices       BTC      Gold    USDGBP  DowJones
# 153 -0.479900         -0.014140 -0.368711 -0.919960 -0.892995  0.618167
# 185 -0.311768          0.427190 -0.611422 -0.740410 -0.064789 -0.238757
# 301  2.583556          0.244774 -0.242073  1.654374  1.004978 -0.257702
# 172 -0.317521          0.244774  0.375743 -0.148126 -0.409280  0.774641
# 46  -0.734974         -0.949760  1.004168 -1.635053 -0.571708 -1.626612
# ..        ...               ...       ...       ...       ...       ...
# 306  2.432684          0.185930 -0.464017  2.593321  1.808196 -0.660074
# 87  -0.633328         -0.784996  1.183946 -0.138799 -0.838257  0.179302
# 197  0.243771          0.868520  0.887761 -0.932396  0.161302  0.316558
# 174 -0.389760          0.315387  0.753710 -0.007440 -0.682373  0.724948
# 122 -0.164732         -0.549620 -1.300997 -0.578737 -1.014965 -0.054574
#
# [273 rows x 6 columns]

# %%
# !pip install python-math
import math
# Out:
# Requirement already satisfied: python-math in c:\users\kwnst\appdata\local\programs\python\python310\lib\site-packages (0.0.1)
# WARNING: You are using pip version 21.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\kwnst\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
C_range = np.arange(1, 101, 5)
epsilon_range = np.arange(0.01,0.1,0.01)


param_grid = dict(C = C_range, epsilon = epsilon_range, )
grid = GridSearchCV(SVR(kernel='linear'), param_grid = param_grid, cv = 3,  n_jobs = 7)  #  3-fold cross-validation
model = grid.fit(X_train, y_train)
print("The best parameters are %s with a score of %0.2f" % (grid.best_params_, grid.best_score_))

clf = SVR(kernel='linear', C = grid.best_params_["C"], epsilon = grid.best_params_["epsilon"])
model_best = clf.fit(X_train, y_train)

y_hat_in_svr_linear = model_best.predict(X_train)
y_hat_out_svr_linear = model_best.predict(X_test)

print("Residual sum of squares: %.3f"
      % np.mean((y_hat_in_svr_linear - y_train) ** 2))
print("Root Mean Square (in-sample): %.3f"
      % math.sqrt(np.mean((y_hat_in_svr_linear - y_train)**2)))

print("Residual sum of squares: %.3f"
      % np.mean((y_hat_out_svr_linear - y_test) ** 2))
print("Root Mean Square (in-sample): %.3f"
      % math.sqrt(np.mean((y_hat_out_svr_linear - y_test)**2)))
# Out:
# The best parameters are {'C': 1, 'epsilon': 0.02} with a score of 0.94
# Residual sum of squares: 0.053
# Root Mean Square (in-sample): 0.231
# Residual sum of squares: 0.054
# Root Mean Square (in-sample): 0.231

# %%
C_range = np.arange(1, 101, 5)
gamma_range=np.arange(1, 101, 5)
epsilon_range = np.arange(0.01,0.1,0.01)

param_grid = dict(gamma=gamma_range, C=C_range, epsilon=epsilon_range, )
grid = GridSearchCV(SVR(kernel='rbf'), param_grid=param_grid, cv=10,  n_jobs=7)  #  5-fold cross-validation
model = grid.fit(X_train, y_train)
print("The best parameters are %s with a score of %0.2f" % (grid.best_params_, grid.best_score_))

clf2=SVR(kernel='rbf', C=grid.best_params_["C"], epsilon=grid.best_params_["epsilon"], gamma=grid.best_params_["gamma"])
model_best=clf2.fit(X_train, y_train)

y_hat_in_svr_rbf = model_best.predict(X_train)
y_hat_out_svr_rbf = model_best.predict(X_test)

print("Residual sum of squares: %.3f"
      % np.mean((y_hat_in_svr_rbf - y_train) ** 2))
print("Root Mean Square (in-sample): %.3f"
      % math.sqrt(np.mean((y_hat_in_svr_rbf - y_train)**2)))

print("Residual sum of squares: %.3f"
      % np.mean((y_hat_out_svr_rbf - y_test) ** 2))
print("Root Mean Square (out-of-sample): %.3f"
      % math.sqrt(np.mean((y_hat_out_svr_rbf - y_test)**2)))
# Out:
# The best parameters are {'C': 6, 'epsilon': 0.03, 'gamma': 1} with a score of 0.95
# Residual sum of squares: 0.001
# Root Mean Square (in-sample): 0.031
# Residual sum of squares: 0.060
# Root Mean Square (out-of-sample): 0.244

# %%
print('------------------------SVR-Linear---------------------')
print("Root Mean Square (in-sample):  %.3f"
      % math.sqrt(np.mean((y_hat_in_svr_linear - y_train)**2)))
print("Root Mean Square (out-of-sample):  %.3f"
      % math.sqrt(np.mean((y_hat_out_svr_linear - y_test)**2)))
print('------------------------SVR-RBF------------------------')
print("Root Mean Square (in-sample):  %.3f"
      % math.sqrt(np.mean((y_hat_in_svr_rbf - y_train)**2)))
print("Root Mean Square (out-of-sample):  %.3f"
      % math.sqrt(np.mean((y_hat_out_svr_rbf - y_test)**2)))
print('-------------------------------------------------------')
# Out:
# ------------------------SVR-Linear---------------------
# Root Mean Square (in-sample):  0.231
# Root Mean Square (out-of-sample):  0.231
# ------------------------SVR-RBF------------------------
# Root Mean Square (in-sample):  0.031
# Root Mean Square (out-of-sample):  0.244
# -------------------------------------------------------

# %%
import itertools
X_new = df[['OilPrice',	'NaturalGasPrices', 'BTC', 'Gold', 'USDGBP', 'DowJones']].copy()
y_new = df['USDEUR'].copy()

X_new = X_new.fillna(X_new.mean())   #replace NaNs with the mean value
y_new = y_new.fillna(y_new.mean())   #replace NaNs with the mean value


X_train_new, X_test_new, y_train_new, y_test_new = train_test_split( X_new, y_new, test_size=0.2, random_state=4)

mean_X_train_new=np.mean(X_train_new)
std_X_train_new=np.std(X_train_new)
X_train_new=(X_train_new-mean_X_train_new)/std_X_train_new

mean_y_train_new=np.mean(y_train_new)
std_y_train_new=np.std(y_train_new)
y_train_new=(y_train_new-mean_y_train_new)/std_y_train_new

## apply same transformation to test data
X_test_new = (X_test_new-mean_X_train_new)/std_X_train_new  # remove mean and standard deviation from test
y_test_new = (y_test_new-mean_y_train_new)/std_y_train_new


C_range = np.arange(1, 11, 5)
gamma_range=np.arange(1, 11, 5)
epsilon_range = np.arange(0.01,0.3,0.1)

param_grid = dict(gamma=gamma_range, C=C_range, epsilon=epsilon_range, )
grid = GridSearchCV(SVR(kernel='rbf'), param_grid=param_grid, cv=10,  n_jobs=7)  #  5-fold cross-validation

featureList =  ['OilPrice',	'NaturalGasPrices', 'BTC', 'Gold', 'USDGBP', 'DowJones']
numInputs = 2
AllParms = []
AllParms = list(itertools.combinations(featureList, numInputs))

# Create a list of integers to identify the iteration, i1, i2, i3, etc.
iteration = list(range(1, len(AllParms) + 1))

rmse=[]

# Loop thru files
for j in range(len(AllParms)):
    nAllParms=list(AllParms[j]) 
    model = grid.fit(X_train_new[nAllParms], y_train_new)
    y_out = model.predict(X_test_new[nAllParms])
    rmse.append(math.sqrt(np.mean((y_out - y_test_new)**2)))
    
print(rmse)
# Out:
# [0.4296693112194659, 0.38567679712096764, 0.3676845972772827, 0.21738405597722585, 0.38661792856532423, 0.45812124045469604, 0.4717892075205658, 0.2762433716428565, 0.48882436208033286, 0.6995001222382019, 0.4270220300659604, 0.6782241367757165, 0.44527061302367904, 0.5896770228987837, 0.24334223774044866]

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.1, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (307, 6) (307,)
# Test set: (35, 6) (35,)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
C_range = np.arange(1, 101, 5)
epsilon_range = np.arange(0.01,0.1,0.01)
# print(C_range,epsilon_range)

param_grid = dict(C = C_range, epsilon = epsilon_range, )
grid = GridSearchCV(SVR(kernel='linear'), param_grid = param_grid, cv = 5,  n_jobs = 7)  #  5-fold cross-validation
model = grid.fit(X_train, y_train)
print("The best parameters are %s with a score of %0.2f" % (grid.best_params_, grid.best_score_))

clf = SVR(kernel='linear', C = grid.best_params_["C"], epsilon = grid.best_params_["epsilon"])
model_best = clf.fit(X_train, y_train)

y_hat_in_svr_linear = model_best.predict(X_train)
y_hat_out_svr_linear = model_best.predict(X_test)

print("Residual sum of squares: %.3f"
      % np.mean((y_hat_in_svr_linear - y_train) ** 2))
print("Root Mean Square (in-sample): %.3f"
      % math.sqrt(np.mean((y_hat_in_svr_linear - y_train)**2)))

print("Residual sum of squares: %.3f"
      % np.mean((y_hat_out_svr_linear - y_test) ** 2))
print("Root Mean Square (in-sample): %.3f"
      % math.sqrt(np.mean((y_hat_out_svr_linear - y_test)**2)))
# Out:
# The best parameters are {'C': 1, 'epsilon': 0.060000000000000005} with a score of 0.46
# Residual sum of squares: 0.001
# Root Mean Square (in-sample): 0.028
# Residual sum of squares: 0.001
# Root Mean Square (in-sample): 0.029

# %%
C_range = np.arange(1, 101, 5)
gamma_range=np.arange(1, 101, 5)
epsilon_range = np.arange(0.01,0.1,0.01)

param_grid = dict(gamma=gamma_range, C=C_range, epsilon=epsilon_range, )
grid = GridSearchCV(SVR(kernel='rbf'), param_grid=param_grid, cv=5,  n_jobs=7)  #  5-fold cross-validation
model = grid.fit(X_train, y_train)
print("The best parameters are %s with a score of %0.2f" % (grid.best_params_, grid.best_score_))

clf2=SVR(kernel='rbf', C=grid.best_params_["C"], epsilon=grid.best_params_["epsilon"], gamma=grid.best_params_["gamma"])
model_best=clf2.fit(X_train, y_train)

y_hat_in_svr_rbf = model_best.predict(X_train)
y_hat_out_svr_rbf = model_best.predict(X_test)

print("Residual sum of squares: %.3f"
      % np.mean((y_hat_in_svr_rbf - y_train) ** 2))
print("Root Mean Square (in-sample): %.3f"
      % math.sqrt(np.mean((y_hat_in_svr_rbf - y_train)**2)))

print("Residual sum of squares: %.3f"
      % np.mean((y_hat_out_svr_rbf - y_test) ** 2))
print("Root Mean Square (out-of-sample): %.3f"
      % math.sqrt(np.mean((y_hat_out_svr_rbf - y_test)**2)))
# Out:
# The best parameters are {'C': 1, 'epsilon': 0.01, 'gamma': 1} with a score of -0.02
# Residual sum of squares: 0.000
# Root Mean Square (in-sample): 0.010
# Residual sum of squares: 0.002
# Root Mean Square (out-of-sample): 0.040

# %%
import itertools
X_new = df[['OilPrice',	'NaturalGasPrices', 'BTC', 'Gold', 'USDGBP', 'DowJones']].copy()
y_new = df['USDEUR'].copy()

X_new = X_new.fillna(X_new.mean())   #replace NaNs with the mean value
y_new = y_new.fillna(y_new.mean())   #replace NaNs with the mean value


X_train_new, X_test_new, y_train_new, y_test_new = train_test_split( X_new, y_new, test_size=0.1, random_state=4)

mean_X_train_new=np.mean(X_train_new)
std_X_train_new=np.std(X_train_new)
X_train_new=(X_train_new-mean_X_train_new)/std_X_train_new

mean_y_train_new=np.mean(y_train_new)
std_y_train_new=np.std(y_train_new)
y_train_new=(y_train_new-mean_y_train_new)/std_y_train_new

## apply same transformation to test data
X_test_new = (X_test_new-mean_X_train_new)/std_X_train_new  # remove mean and standard deviation from test
y_test_new = (y_test_new-mean_y_train_new)/std_y_train_new


C_range = np.arange(1, 11, 5)
gamma_range=np.arange(1, 11, 5)
epsilon_range = np.arange(0.01,0.3,0.1)

param_grid = dict(gamma=gamma_range, C=C_range, epsilon=epsilon_range, )
grid = GridSearchCV(SVR(kernel='rbf'), param_grid=param_grid, cv=5,  n_jobs=7)  #  5-fold cross-validation

featureList =  ['OilPrice',	'NaturalGasPrices', 'BTC', 'Gold', 'USDGBP', 'DowJones']
numInputs = 2
AllParms = []
AllParms = list(itertools.combinations(featureList, numInputs))

# Create a list of integers to identify the iteration, i1, i2, i3, etc.
iteration = list(range(1, len(AllParms) + 1))

rmse=[]

# Loop thru files
for j in range(len(AllParms)):
    nAllParms=list(AllParms[j]) 
    model = grid.fit(X_train_new[nAllParms], y_train_new)
    y_out = model.predict(X_test_new[nAllParms])
    rmse.append(math.sqrt(np.mean((y_out - y_test_new)**2)))
    
print(rmse)
# Out:
# [0.43589128203930017, 0.38649750558881196, 0.4221569191676118, 0.20550986102320618, 0.4269850288319543, 0.4724458844510124, 0.4094828914874064, 0.2736642478692478, 0.46798563198560517, 0.6844432609476753, 0.4387321943738438, 0.6541358305925763, 0.47045896555883665, 0.5261792780078295, 0.17434421420128923]
